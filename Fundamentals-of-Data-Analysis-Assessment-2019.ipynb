# %% [markdown]
# ![Image](Images/pythonpandas.JPG "Image")
#
# This is an investigation in to the well known tips dataset. This investigation is divided in to three parts see links below.<BR>
#
# [1. Description](#1.-Description)
#
# [2. Regression](#2.-Regression)
#
# [3. Analyse](#3.-Analyse)

# %% [markdown]
# # 1. Description
#
# In this section we will look and discuss the descriptive statistics of the tips dataset
#
#
# #### References:
# https://data-flair.training/blogs/python-descriptive-statistics/<br>
# https://pandas.pydata.org/pandas-docs/stable/reference/frame.html<br>
# https://towardsdatascience.com/analyze-the-data-through-data-visualization-using-seaborn-255e1cd3948e<br>
# https://datascienceplus.com/seaborn-categorical-plots-in-python/<br>

# %% [markdown]
# ### Importing Python Packages

# %%
#The following packages are imported to be used throughout this jupyter notebook
#Import pandas and call in pd
import pandas as pd
#Import Matplotlib
import matplotlib.pyplot as plt
#Import Seaborn plotting library
import seaborn as sns
#Import Numpy library as np
import numpy as np

# %% [markdown]
# ### Importing Tip Dataset

# %%
# Using pandas command 'pd.read_csv' the tips dataset is imported from a csv file at the URL below and assigned to the 
# variable df, this file could also have been saved locally and imported.
# The tips dataset is also available in Seaborn

df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# %%
#Prints the tips dataset Dataframe 'df' thats impored from the url https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %% [markdown]
# Printing the imported dataframe variable above **df** yields 244 rows or entries in this dataset, there are seven variables three of which are numeric and four which categorise the entry.
#
# The numeric variables are total_bill, tips, size. This is the tip amount from the total bill and how many people sat at the table.
#
# The other four variables categorise or group the entries by gender, smoker or non smoker, what day they were in the restuarant and what time of day they were there either lunchtime or dinnertime.

# %% [markdown]
# ### Descriptive Statistics

# %%
#Gives overall stats from the dataset, it includes all numeric columns
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# The Pandas function **df.describe** above gives the overall statistics for the numeric columns on the dataset. This includes the following
# - Count: How many entries in the data set from each numeric column
# - mean: The mean value of each of the numeric columns
# - std: Standard Devation from the mean
# - Min: Min value
# - 25%, 50% & 75%: Percentile
# - Max: Max value

# %% [markdown]
# #### Gender Differences
# We will look at the differences between whether the bill payer was male or female and see if there is a significant difference.

# %%
#Display the summary stats for a rows sex/Male of the dataset
df.loc[df.loc[:,'sex'] == 'Male'].describe()
# Out:
#        total_bill         tip        size
# count  157.000000  157.000000  157.000000
# mean    20.744076    3.089618    2.630573
# std      9.246469    1.489102    0.955997
# min      7.250000    1.000000    1.000000
# 25%     14.000000    2.000000    2.000000
# 50%     18.350000    3.000000    2.000000
# 75%     24.710000    3.760000    3.000000
# max     50.810000   10.000000    6.000000

# %%
#Display the summary stats for a rows sex/Female of the dataset
df.loc[df.loc[:,'sex'] == 'Female'].describe()
# Out:
#        total_bill        tip       size
# count   87.000000  87.000000  87.000000
# mean    18.056897   2.833448   2.459770
# std      8.009209   1.159495   0.937644
# min      3.070000   1.000000   1.000000
# 25%     12.750000   2.000000   2.000000
# 50%     16.400000   2.750000   2.000000
# 75%     21.520000   3.500000   3.000000
# max     44.300000   6.500000   6.000000

# %% [markdown]
# From the statistics of male and female above it can be seen that there are significantly more male bill payers, there is not much between the mean of either total_bill or tip. There is a bit more in the max total_bill and tip for male than female.

# %%
#This Seaborn count plot simply takes the column sex plots it on the x-axis this counts the values Male and Female 
#and plots them on this plot.
#From the values above there are 87 Female and 157 Male. 
sns.countplot(x='sex',data=df)
plt.title("Female vs Male")
plt.show()

# %% [markdown]
# The Seaborn count plot above shows the numbers of female vs male bill payers side by side you can see there are nearly twice as many male bill payers than female.

# %%
dfmale = df.loc[df.loc[:,'sex'] == 'Male']
dffemale = df.loc[df.loc[:,'sex'] == 'Female']

sns.distplot(dfmale['total_bill'], hist=True, kde=False, label = 'Male', color='blue')
sns.distplot(dffemale['total_bill'], hist=True, kde=False, label = 'Female' , color='red')
plt.legend()
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# It can be seen from the statistics and that there are approximately 2/3 male to 1/3 female bill payers. It can be seen from the plot above that the majority of the female bills are between 10 & 20. The majority of the male are between 12 & 28, it can be seen that the male bills are on average higher than the female bills.

# %%
sns.distplot(dfmale['total_bill'], hist=True, kde=True, label = 'Male', color='green')
sns.distplot(dffemale['total_bill'], hist=True, kde=True, label = 'Female' , color='red')
plt.legend()
plt.show()

# %% [markdown]
# The plot above shows a the probability distribution for total_bill in the male and female category, the highest probability of a male bill is 0.5 and that amount was approx 18. The female bill probability was over 0.6 at 15

# %%
#The Seaborn category scatter plot can be useful in comparing one group directly against against another
sns.catplot(x="sex", y="tip", data=df);
plt.title("Tips Female vs Male")
plt.show()

# %% [markdown]
# From the Category Scatter plot above is can be seen that male and female tips are mostly the same amount except for the higher amounts from a tip of 5.5 upwards. It also can be see that there are many more dots on the male side indicating more male this is also clearer in the earlier plots.

# %% [markdown]
# ### Plotting Variables from the Dataset
# We will start by plotting the variable tip in from the dataset. We will look at two plots a histogram that indicates the occurances of the quantites of the tip and we will also look at the Kernal Density Estimate this will indicate the probability distribution of the tip amount.

# %% [markdown]
# #### Univariate Plots.
#
# Univariate plots describe single variables in a dataset this does not analyse relationships between variables like regression. Univariate plots can give useful information on single variables in a dataset.
#
# In this section a few variables are plotted from the tips dataset to visualise the information as a whole from a particular variable.
#
# Univariate plots can be plotted as a histogram with actual quantities or the variable occuring or as a Kernal Density Estimate (KDE) this is the probabiliy distribution of a variable.
#
# #### Reference
# https://www.statisticshowto.datasciencecentral.com/univariate/<br>
# https://www.quora.com/What-is-the-difference-between-simple-histogram-estimation-and-that-of-kernel-density-estimation-of-a-set-of-datas-distribution

# %% [markdown]
# #### Tip Histogram

# %%
# Variable tip is plotted

sns.distplot(df['tip'], kde=False, bins=20);
plt.title("Occurances of tip Amount")
plt.show()

# %% [markdown]
# It can be seen that a lot of tips fall between 2 & 4 with the max amount of 2 tip is approx 55 times. A tip of 3 is given about 40 times.

# %% [markdown]
# #### Tip Kernel Density Estimate
#
# The Kernal Density Estimate plot is created for the variable tip.

# %%
# The Kernel Density Estimate is a method to estimate the probability density function of a continous random variable,
sns.distplot(df['tip'], hist=False, bins=20);
plt.title("Probability of tip Amount")
plt.show()

# %% [markdown]
# It can be seen from the plot above that the probability of the tip is between 2 is the highest spike of getting a tip between 2 & 4 based on the data.

# %% [markdown]
# #### Total_bill Histogram

# %%
# Variable total_bill is plotted

sns.distplot(df['total_bill'], kde=False, bins=20);
plt.title("Occurances of total_bill Amount")
plt.show()

# %% [markdown]
# From the histogram above it can be seen that the total_bill of 18 occured over 35 times this is the highest occurance of the total_bill amount

# %% [markdown]
# #### Total_bill Kernel Density Estimate
#
# The Kernal Density Estimate plot is created for the variable total_bill.

# %%
# The Kernel Density Estimate is a method to estimate the probability density function of a continous random variable,
sns.distplot(df['total_bill'], hist=False, kde=True, bins=20);
plt.title("Probability of total_bill Amount")
plt.show()

# %% [markdown]
# From the Kernal Density Estimate graph the probability distrbution of the total_bill amount of 18 is highest indicated by the spike.

# %% [markdown]
# #### Size Histogram Plot
# The party size is plotted as a histogram

# %%
# Size total_bill is plotted

sns.distplot(df['size'], kde=False, bins=20);
plt.title("Occurances of party size")
plt.show()

# %% [markdown]
# From the histogram above it can be seen the most common party size is two at slightly under 160 and the next most party size is 3 & 4 at 40 each. Parties of 1, 5 & 6 are not as common.

# %% [markdown]
# #### Size Kernel Density Estimate
# The Kernal Density Estimate plot is created for the variable size.

# %%
# The Kernel Density Estimate plot for variable size
sns.distplot(df['size'], hist=False, bins=20);
plt.title("Probability distribution of party size")
plt.show()

# %% [markdown]
# The probability density distrbution plot follows the histogram above with the largest spike at party size of 2, follows by two smaller but even spikes at 3 & 4 and ripples at 1, 5 & 6.

# %% [markdown]
# ### Conclusions
# From this section the following conclusions are made:
#
#    * They are twice as many male to female bill payers
#    * There is not much to separate the mean male and female total_bill or tip amount
#    * The higher total_bills tend to be male therefore the higher tip tend to be male.
#    * The most common tip is 2
#    * The most common bill amount is 18
#    * The most common size is a party of 2 followed by 3 & 4

# %% [markdown]
# # 2. Regression

# %% [markdown]
# In this section we will discuss Regression. Regression is one of the main areas of research in Data Analysis. Regression can be used to to see if there is a relationship between an independent variable and dependent variable, the regression statistics can be used to predict the value of the dependent variable when the independent variable is known. We will look at plotting the **total_bill** versus **tip**.
#
# In regression analysis the independent variable is known as the x-value and the dependent variable is known as the y-value
#
# From the tips dataset the variables assigned to x & y are given below
#
# x = total_bill<br>
# y = tip<br>
#
# x is the independent variable and y is the dependent variable.
#
# References:<br>
# http://www.stat.yale.edu/Courses/1997-98/101/linreg.htm<br>
# https://en.wikipedia.org/wiki/Least_squares<br>
# https://seaborn.pydata.org/tutorial/regression.html<br>
# http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/BS704_Multivariable/BS704_Multivariable5.html<br>

# %%
#The relationship between total_bill and tips is plotted with a scatter plot
#This is a magic command to ensure the plot is displayed in Jupyter notebook
# %matplotlib inline
#The plt.plot function is used, the variable values are 'total_bill' and 'tip' are pulled directly from the dataframe 'df' using the loc function
#The values are plotted as green triangles and labeled original data
plt.plot(df.loc[:,'total_bill'], df.loc[:,'tip'], 'g^' , label='Original data')
#The next three lines adds a title and labels the x & y axis
plt.title('Tip vs Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
#plt.legend() displayed the legend
plt.legend()
#plt.show() displays the plot
plt.show()

# %% [markdown]
# The scatter plot shows a direct or positive relationship between **total_bill** and **tip**. The higher the total_bill is the higher the tip is likely to be, similarily a low total_bill would result in a lower tip.

# %% [markdown]
# ### Linear Regression Cost
#
# We will use linear regression analysis to demonstrate there is a positive linear relationship between the independent variable **total_bill** and the dependent variable **tip**. To do this we will calculate and plot a best fit line that is represent the trend of each x & y point of these variables in the tips dataset. This will be represented by a best fit line.
#
# The best line is determined by minimising the following summation formula of all the points of the scatter plot, this method is called the **least squares fitting** formula.
#
# $\sum_i  (y_i - mx_i - c)^2$
#
# Each variable of the formula and its description is given below.
#
# - i = number of x & y values in the dataset that have to be squared and summed above.<br>
# - x = total_bill, the value of y (tip) is dependent on the value of x. <br>
# - y = tip value<br>
# - m = slope of the line<br>
# - c = Value of Y axis when x = 0 or Y intercept.<br>
#
# $y_i - mx_i - c$ is determined mathematically from the formula $y_i = mx_i + c$ which is a straight line with a slope of **m, c** is a constant, i.e the value of y when x = 0 or the Y intercept.
#
# $y_i - mx_i - c$ is the measured value from the dataset so for each value of $y_i$ there is a corresponding value $x_i.$
#
# $y_i = mx_i + c$ is the modeled value this is the straight line
#
# The summation formula is the sum of all the distances each value of x & y (i) or points on the scatter plot is away from a straight line, the (i) or point on the scatter plot can be either above or below the line.
#
# For each value of i the summation is performed. The best fit line will have the minimum distance from all the points on the plot as a whole. As some points will be above the line and some points will be below the line there will be negative numbers this will not yield the desired result. One possible solution is to take the absolute value from the negative numbers and use it as a positive value, it is easier to simply square all the numbers. If you square a negative or a positive number you will get a positive number.
#
# We need to find out the distance each dot is from a line and sum this total, the best line will be the lowest value or **Cost(m, c)** of the sum total of each dot's distance from the line. For example if all the dots were on a straight line then the cost would be zero hence the name **least squares fitting** formula.
#
# From the data we need to find the best value for m & c that will yield the lowest cost and therefore the best fit line to the values total_bill and tip.

# %% [markdown]
# ### Minimising the Cost Calculation using Calculus
#
# The following calculation can be carried to find the miniminm cost for m. When you find m you can calculate c.

# %%
#To find the best values of m for the variables total_bill and tip the following calculation is performed

#Assign total_bill and tip values to arrays
total_bill_values = df.loc[: , "total_bill"]
tip_values = df.loc[: , "tip"]

#Find the mean value of both total_bill & tip and assign this value to two variables using Numpy
avg_totalbill = np.mean(total_bill_values)
avg_tip = np.mean(tip_values)

#Subtract the average or mean values from the original 'total_bill' and 'tip' values for zero values and assign these values to be the zero variables values.
total_bill_values_zero = total_bill_values - avg_totalbill
tip_values_zero = tip_values - avg_tip

#The best m & c is found from the following formula
m = np.sum(total_bill_values_zero * tip_values_zero) / np.sum(total_bill_values_zero * total_bill_values_zero)
# Use m from above to calculate the best c.
c = avg_tip - m * avg_totalbill

#Prints the calculated variable values m & c using formatting of at least 5 digits wide and 8 digits to the right of the decmial point
print("The best value of m is %5.8f and c is %5.8f." % (m, c))
# Out:
# The best value of m is 0.10502452 and c is 0.92026961.

# %% [markdown]
# ### Minimising the Cost Calculation using Python Numpy Polyfit Function
#
# The numpy polyfit function calculates the m and c values, this should be the same answer as the Calculus calculation above.

# %%
#Numpy function that calculates the best value for m & c for a given set of variables. The 1 gives a polynomial of degree 1
np.polyfit(total_bill_values, tip_values, 1)
# Out:
# array([0.10502452, 0.92026961])

# %% [markdown]
# As you can see the **np.polyfit** function calculates the same value for m & c as the Calculus calculation above.

# %% [markdown]
# ### Calculating the Cost
# To calculate the cost of the values of **total_bill** and **tip** the following calculation can be performed from the resulting m & c values
# The Cost can be calculated using the following formula
#
# Cost(m,c) = $\sum_i  (y_i - mx_i - c)^2$
#
# This is given by the code below

# %%
cost = np.sum([(total_bill_values[i] - m * tip_values[i] - c)**2 for i in range(total_bill_values.size)])
print("The cost is %8.2f" % (cost))
# Out:
# The cost is 102806.82

# %%
#Plot the best fit line on the scatter plot used previously plotted original data variables total_bill and tip
#This is a magic command to ensure the plot is displayed in Jupyter notebook
# %matplotlib inline
#The plt.plot function is used, the variable values are 'total_bill' and 'tip' are pulled directly from the assigned variables in the calulation above 
#The values are plotted as green triangles and labeled original data
plt.plot(total_bill_values, tip_values , 'g^' , label='Original data')
#The best fit line is plotted from the formula 'y = mx + c' using the calculated m & c values for each x, y values, this is plotted as a red line and labeled as Best fit line. 
plt.plot(total_bill_values, m * total_bill_values + c, 'r-' , label='Best fit line')
plt.title('Tip vs Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
#plt.legend() displayed the legend
plt.legend()
#plt.show() displays the plot
plt.show()

# %% [markdown]
# ### Linear Regression using Seaborn
#
# There are two functions in Seaborn used to plot linear regression these are
#
# - **sns.regplot**<br>
# - **sns.lmplot**
#
# The next two code cells plot the total_bill vs tip. You will see that the plots while identical to each other are identical to the plot where the best line fit was calculated and plotted in the previous graph.

# %%
sns.regplot(x="total_bill", y="tip", data=df);

# %%
sns.lmplot(x="total_bill", y="tip", data=df);

# %% [markdown]
# ### Conclusion
#
# In conclusion the we can see from the three plots above that there is a positive relationship between the independent variable **total_bill** and its dependent variable **tip**. It can be seen from the plots above that there is a lot of varied tips but in general the **tip** amount is releated to the **total_bill** amount.

# %% [markdown]
# # 3. Analyse

# %% [markdown]
# In this section we will analyse various variables to visualise the data in the data set and drawn some conclusions on it.
#
# References:<br>
# https://towardsdatascience.com/analyze-the-data-through-data-visualization-using-seaborn-255e1cd3948e<br>
# https://datascienceplus.com/seaborn-categorical-plots-in-python/<br>
# https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html<br>
# https://towardsdatascience.com/how-to-filter-rows-of-a-pandas-dataframe-by-column-value-51996ea621f8<br>

# %% [markdown]
# ### Bivariate Plots
# Bivariate plots are used to analyse relationships between pairs of variable in a dataset. In this section we will analyse pairs of variables to get a better understanding of the data in the dataset.

# %% [markdown]
# #### Seaborn Scatter Plot Total Bill vs Tip for Smoker & Non Smoker
# In this Seaborn scatter plot the total_bill and tip are plotted. The column smoker is coloured in to No and Yes from the dataset. This gives use a view if there is a fifference between smokng and non smoking bill payers

# %%
#The seaborn scatter plots total_bill on the x-axis vs tip on the y-axis, category smoker Yes or No is coloured different.
sns.relplot(x="total_bill", y="tip", hue="smoker", data=df);
plt.title("Smoker vs Non Smoker")
plt.show()

# %% [markdown]
# From the Scatter plot above smokers seem to leave less tip than non smokers as the total_bill increases above 25

# %% [markdown]
# #### Seaborn Scatter Plot Total Bill vs Tip for Male & Female
# The seaborn scatter plots nighlights the difference between male and female total_bill v tip. The plot clearly shows that they are more higher male bills than female bills, as we seen in the regression section the higher the total_bill the higher the tip.

# %%
#The seaborn scatter plots total_bill on the x-axis vs tip on the y-axis, category sex Male or Female is coloured different.
sns.relplot(x="total_bill", y="tip", hue="sex", data=df);
plt.title("Male vs Female")
plt.show()

# %% [markdown]
# #### Seaborn Scatter Plot Total Bill vs Tip for party size
# The seaborn scatter plot gives a view of the total_bill vs tip with party size highlighted

# %%
#The seaborn scatter plots total_bill on the x-axis vs tip on the y-axis, category size is coloured different.
sns.relplot(x="total_bill", y="tip", hue="size", data=df);
plt.title("Total Bill, Tip & Size")
plt.show()

# %% [markdown]
# The scatter plot above splits out the party size for total_bill vs tip. It is not surprising that the larger the party the larger the total_bill therefore the larger the tip.

# %% [markdown]
# #### Seaborn Scatter Plot Total Bill vs Tip for time of day
# The seaborn scatter gives us a view of total_bill v tip and time coloured.

# %%
#The seaborn scatter plots total_bill on the x-axis vs tip on the y-axis, category time is coloured different.
sns.relplot(x="total_bill", y="tip", hue="time", data=df);
plt.title("Total Bill, Tip & Time")
plt.show()

# %% [markdown]
# It can be seen that lunches exceed dinners when the total bil is around the 10 region when the total_bill is higher i.e 25 and above there are more occurances of dinner.

# %% [markdown]
# ### Bar Plot
# The bar plot can plot quantities for various categories, the plot below gives a breakdown on the cost of the bill versus the size of the party sitting in the restuarant.

# %% [markdown]
# #### Bar Plot Total Bill for size of party

# %%
sns.barplot(x='size',y='total_bill',data=df)
plt.title("Total Bill vs Size of Party")
plt.show()

# %% [markdown]
# The bar plot above shows that as the party size increase so to does the total_bill

# %% [markdown]
# ### Category Plots

# %% [markdown]
# #### Tip Category Plot for Smokers vs Non-Smokers
# The category plot is used to plot smokers vers non smokers, there are a lot more non-smokers with a larger density of tips from under 2 to just above 4

# %%
#The Seaborn category plot is used to plot smoker on the x-axis the order command is used to order the category values.
#In this case the category is smoker and the order is Yes on the left and No on the right.
sns.catplot(x="smoker", y="tip", order=["Yes", "No"], data=df);
plt.title("Tips for Smoker v Non Smoker")
plt.show()

# %% [markdown]
# There is no obvious difference in the tip amount for smokers vs non-smokers only that there are more non-smokers than smokers due to the higher concentration of orange dots on the right than blue dots on the left.

# %% [markdown]
# #### Tip Category Plot for each Day
# The next category plot below is an example of a box category plot. Tip is plotted on each of the values of column day. The values in day in the tips dataset are Thur, Fri, Sat, Sun.
#
# The box is actually a box and whisker plot. The two whiskers for example give the max value(top) and min value(bottom). On the box itself the bottom of the box represents the 25% quartile, the line is the median and the top of the box is the 75% quartile.

# %%
#The category plot plots the tip as a box plot and orders the days of the week Thur <-> Sun
sns.catplot(x="day", y="tip", kind="box", order=["Thur" , "Fri" , "Sat" , "Sun"], data=df);
plt.title("Total Tip by Day")
plt.show()

# %% [markdown]
# It can be seen from the from the box plot the the average tip increased from Thurs to Fri, it dropped on Saturday, then increased again on Sunday. The 25% - 75% quartile was the same Thur to Sat and increased slightly on Sunday when the 25% - 75% or tip were between 2 & 4.

# %% [markdown]
# #### Tip Category Plot for each Day and Male v Female
# The whisker plot for tip on each day the male v female vvalues are coloured to see if there is any difference between them.

# %%
#A 3rd variable is introduced, column sex is included in the hue statement. The hue colours the sex values differently
sns.catplot(x="day", y="tip", hue="sex", kind="box", order=["Thur" , "Fri" , "Sat" , "Sun"], data=df);
plt.title("Tips by Day and Sex")
plt.show()

# %% [markdown]
# From the box plot above it can be seen that there is a better chance of getting a higher tip if the bill payer is male. But the average tip on Fri and Sunday was higher from Female. The general trend as a waiter you tip is probably going to be higher if the bill payer is male.

# %% [markdown]
# #### Tip Category plot for Time of Day and Day of the week
# This category whisker plot highlights the time of day and the days of the week

# %%
# This Category plot plots tip for Lunch and dinner and colours the day with the hue statment.
sns.catplot(x="time", y="tip", hue="day", kind="box", order=["Lunch" , "Dinner"], data=df);
plt.title("Tips from Time and Day")
plt.show()

# %% [markdown]
# The category plot above tells us that there is mostly Lunch on Thursday, Friday Lunch and Dinner have enough numbers to show on the graph. Saturday and Sunday mostly Dinner.
#
# The trend is bigger tips towards the weekend.

# %% [markdown]
# ### Filtering the Dataset
#
# We will look at splitting up the dataset pandas dataframe to look at various statistics on from the dataset by categories such as time of sitting, day of the week, smoker or non-smoker, if the tip or total_bill was over a certain value

# %% [markdown]
# #### Filter by String Variable
#
# The tips dataset can be split in to categories on the day of the week by running the following code assigning it to a new dataframe and printing the resulting statistics.

# %% [markdown]
# The code below demonstrated how to filter the statset on a string value in a particular, the code also assigned the filtered data to a new dataframe. The example filters column "day" but this can be done to any column with a string.

# %%
# Filter the original dataset by column day with the string value day of the week and assign it to a new datafram variable

dfthur = df[df.day == 'Thur']
dffri = df[df.day == 'Fri']
dfsat = df[df.day == 'Sat']
dfsun = df[df.day == 'Sun']

#The summary statistics can be print to demonstrate the filter dataset subset.
dfthur.head
dffri.describe()
# Out:
#        total_bill        tip       size
# count   19.000000  19.000000  19.000000
# mean    17.151579   2.734737   2.105263
# std      8.302660   1.019577   0.567131
# min      5.750000   1.000000   1.000000
# 25%     12.095000   1.960000   2.000000
# 50%     15.380000   3.000000   2.000000
# 75%     21.750000   3.365000   2.000000
# max     40.170000   4.730000   4.000000

# %% [markdown]
# #### Filtering by Numeric Value
#
# In this section the columns are filtered using a numeric value in the columns

# %%
# Find out who gave 1.00 or less of a tip. The code filters the numeric value in column tip at 1.00 or less
df_tips_low = df[df.tip <= 1.00]
df_tips_low
# Out:
#      total_bill  tip     sex smoker  day    time  size
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1
# 92         5.75  1.0  Female    Yes  Fri  Dinner     2
# 111        7.25  1.0  Female     No  Sat  Dinner     1
# 236       12.60  1.0    Male    Yes  Sat  Dinner     2

# %% [markdown]
# The code filters the tip on 1.00 or less, as you can see that not many people gave 1.00 as a tip, nobody gave less that 1.00. 3 the 4 were female but the male bill was 12.60 for his 1.00 tip.

# %% [markdown]
# ### Pairplots on Tips Dataset
# In this section we will look at pairplots to compare multiple variables. The three pairplots below are plotted for the entire dataset colouring columns such as day, smoker and time, this gives a lot of the information that we have seen before on one large plots divided in to subplots.
#
# Reference:<br>
# https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166

# %% [markdown]
# #### Seaborn Pairplot highlighting each Day

# %%
sns.pairplot(df, hue='day')
plt.show()

# %% [markdown]
# #### Seaborn Pairplot highlighting Smoker

# %%
sns.pairplot(df, hue='smoker')
plt.show()

# %% [markdown]
# #### Seaborn Pairplot highlighting Time of the time

# %%
sns.pairplot(df, hue='time')
plt.show()

# %% [markdown]
# ### Conclusions
#    * There is not much of a difference between smoking and non smoking bill payers, except for when the bills get higher ie over 25 smoking bill payers leave less tip.
#    * There are more occurances of higher male total_bills than female. Male Female bills and tips are evenly matched up to where the bill exceeds approx 25
#    * The total_bill amount increases as the size of the party increases as does the tip.
#    * The time of day has an effect on the total_bill and therefore the tip, with more lunches in the lower total_bill and tip amount, while dinner is more frequent in the higher total_bill and tip amount.
#    * There is not much of a difference between smokers vs non-smokers in the amount of tip, the only obvious difference there are more non-smokers that smokers.
#    * The average tip increases from Thurs to Fri, it drops on Saturday, then increases again on Sunday.
#    * There is a better chance of getting a higher tip if the bill payer is male. But the average tip on Fri and Sunday was higher from Female. The general trend as a waiter your tip is probably going to be higher if the bill payer is male and its dinner time at the weekend.
#    * On Thur lunch was more common, Friday was a mix of Lunches and Dinners, while majority of sittings were Dinner on Saturday and Sunday. The general trend that total_bills and therefore tips were higher at the weekend during Dinner time.
#    * There is lots of information you can get from filtering the dataset by the days of the week or on the amount of tip, for example the dataset was filtered for tips equal or under 1.00, we found there were no tips under 1.00 there were four at 1.00, that is a very small percentage out of 244 samples, 3/4 of these 1.00 tips were female but the total_bill was low, the single male who left 1.00 tip had the highest total_bill out of the four, it was a party size of 2 and he was a smoker.
#    * The seaborn pairplots give a summary of the data that was plotted in separate plots in one large plot containing subplots
